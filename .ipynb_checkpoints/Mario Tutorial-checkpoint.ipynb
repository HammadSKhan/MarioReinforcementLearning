# %% [markdown]
# # 1. Setup Mario

# %%
# !pip install gym_super_mario_bros==7.3.0 nes_py
# Out:
# Requirement already satisfied: gym_super_mario_bros==7.3.0 in c:\users\hammad\anaconda3\lib\site-packages (7.3.0)
# Requirement already satisfied: nes_py in c:\users\hammad\anaconda3\lib\site-packages (8.2.1)
# Requirement already satisfied: gym>=0.17.2 in c:\users\hammad\anaconda3\lib\site-packages (from nes_py) (0.21.0)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\hammad\anaconda3\lib\site-packages (from nes_py) (4.65.0)
# Requirement already satisfied: pyglet<=1.5.21,>=1.4.0 in c:\users\hammad\anaconda3\lib\site-packages (from nes_py) (1.5.21)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\hammad\anaconda3\lib\site-packages (from nes_py) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\hammad\anaconda3\lib\site-packages (from gym>=0.17.2->nes_py) (2.0.0)
# Requirement already satisfied: colorama in c:\users\hammad\anaconda3\lib\site-packages (from tqdm>=4.48.2->nes_py) (0.4.6)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hammad\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hammad\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hammad\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hammad\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hammad\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hammad\anaconda3\lib\site-packages)

# %%
# Import the game
import gym_super_mario_bros
# Import the Joypad wrapper
from nes_py.wrappers import JoypadSpace
# Import the SIMPLIFIED controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
# Setup game
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %%
# Create a flag - restart or not
done = True
# Loop through each frame in the game
for step in range(100000): 
    # Start the game to begin with 
    if done: 
        # Start the gamee
        env.reset()
    # Do random actions
    state, reward, done, info = env.step(env.action_space.sample())
    # Show the game on the screen
    env.render()
# Close the game
env.close()
# Out:
# C:\Users\hammad\anaconda3\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in scalar subtract
#   return (self.ram[0x86] - self.ram[0x071c]) % 256

# %% [markdown]
# # 2. Preprocess Environment

# %%
# Install pytorch
# !pip install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio===0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html

# %%
# Install stable baselines for RL stuff
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\hammad\anaconda3\lib\site-packages (1.8.0)
# Requirement already satisfied: cloudpickle in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: matplotlib in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.7.1)
# Requirement already satisfied: torch>=1.11 in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: pandas in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.5.3)
# Requirement already satisfied: importlib-metadata~=4.13 in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.13.0)
# Requirement already satisfied: gym==0.21 in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: numpy in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.24.3)
# Requirement already satisfied: ale-py==0.7.4 in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: opencv-python in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.7.0.72)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.0 in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.11.2)
# Requirement already satisfied: tqdm in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.65.0)
# Requirement already satisfied: psutil in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: pillow in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (9.4.0)
# Requirement already satisfied: rich in c:\users\hammad\anaconda3\lib\site-packages (from stable-baselines3[extra]) (13.3.5)
# Requirement already satisfied: importlib-resources in c:\users\hammad\anaconda3\lib\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.12.0)
# Requirement already satisfied: requests in c:\users\hammad\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.29.0)
# Requirement already satisfied: click in c:\users\hammad\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (8.0.4)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\hammad\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\hammad\anaconda3\lib\site-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (3.11.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hammad\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\hammad\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\hammad\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in c:\users\hammad\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.38.4)
# Requirement already satisfied: protobuf<4,>=3.9.2 in c:\users\hammad\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.19.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\hammad\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (66.0.0)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\hammad\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.51.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\hammad\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in c:\users\hammad\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hammad\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\hammad\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: jinja2 in c:\users\hammad\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: sympy in c:\users\hammad\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (1.10.1)
# Requirement already satisfied: typing-extensions in c:\users\hammad\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (4.5.0)
# Requirement already satisfied: filelock in c:\users\hammad\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (3.9.0)
# Requirement already satisfied: networkx in c:\users\hammad\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (2.8.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\hammad\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hammad\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hammad\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hammad\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hammad\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\hammad\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hammad\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hammad\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2022.7)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\hammad\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hammad\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.15.1)
# Requirement already satisfied: colorama in c:\users\hammad\anaconda3\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hammad\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\hammad\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hammad\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hammad\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\hammad\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hammad\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hammad\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hammad\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hammad\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hammad\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hammad\anaconda3\lib\site-packages (from jinja2->torch>=1.11->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\hammad\anaconda3\lib\site-packages (from sympy->torch>=1.11->stable-baselines3[extra]) (1.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\hammad\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\hammad\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hammad\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hammad\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hammad\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hammad\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hammad\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hammad\anaconda3\lib\site-packages)

# %%
# Import Frame Stacker Wrapper and GrayScaling Wrapper
from gym.wrappers import GrayScaleObservation
# Import Vectorization Wrappers
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
# Import Matplotlib to show the impact of frame stacking
from matplotlib import pyplot as plt

# %%
# 1. Create the base environment
env = gym_super_mario_bros.make('SuperMarioBros-v0')
# 2. Simplify the controls 
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# 3. Grayscale
env = GrayScaleObservation(env, keep_dim=True)
# 4. Wrap inside the Dummy Environment
env = DummyVecEnv([lambda: env])
# 5. Stack the frames
env = VecFrameStack(env, 4, channels_order='last')

# %%
state = env.reset()

# %%
state, reward, done, info = env.step([5])

# %%
plt.figure(figsize=(20,16))
for idx in range(state.shape[3]):
    plt.subplot(1,4,idx+1)
    plt.imshow(state[0][:,:,idx])
plt.show()

# %% [markdown]
# # 3. Train the RL Model

# %%
# Import os for file path management
import os 
# Import PPO for algos
from stable_baselines3 import PPO
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %%
# This is the AI model started
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, 
            n_steps=512)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
# Train the AI model, this is where the AI model starts to learn
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Logging to ./logs/PPO_1
# C:\Users\hammad\anaconda3\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in scalar subtract
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ----------------------------
# | time/              |     |
# |    fps             | 78  |
# |    iterations      | 1   |
# |    time_elapsed    | 6   |
# |    total_timesteps | 512 |
# ----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 12            |
# |    iterations           | 2             |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 1024          |
# | train/                  |               |
# |    approx_kl            | 1.6848673e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00289      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 174           |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -8.6e-05      |
# |    value_loss           | 500           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 3            |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 6.227358e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.0158      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.12         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000533    |
# |    value_loss           | 2.25         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 4             |
# |    time_elapsed         | 234           |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 1.9814586e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.017        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.152         |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000352     |
# |    value_loss           | 0.975         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 5            |
# |    time_elapsed         | 308          |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 6.394461e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0182       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.173        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000112    |
# |    value_loss           | 0.905        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 6             |
# |    time_elapsed         | 381           |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 3.0633528e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0191        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.195         |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -2.68e-05     |
# |    value_loss           | 0.532         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 7             |
# |    time_elapsed         | 454           |
# |    total_timesteps      | 3584          |
# | train/                  |               |
# |    approx_kl            | 4.9695373e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0085        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0745        |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -8.18e-05     |
# |    value_loss           | 0.356         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 8           |
# |    time_elapsed         | 530         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 3.54636e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | -0.0214     |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0629      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -6.2e-05    |
# |    value_loss           | 0.266       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 9             |
# |    time_elapsed         | 607           |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 1.2586359e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00857      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0994        |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000312     |
# |    value_loss           | 0.3           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 10           |
# |    time_elapsed         | 688          |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 7.385155e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0114       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0827       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000179    |
# |    value_loss           | 0.255        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 11            |
# |    time_elapsed         | 767           |
# |    total_timesteps      | 5632          |
# | train/                  |               |
# |    approx_kl            | 1.6685459e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00306       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0951        |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000366     |
# |    value_loss           | 0.278         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 12          |
# |    time_elapsed         | 848         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 1.04137e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | -0.00735    |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0769      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.000202   |
# |    value_loss           | 0.163       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 13            |
# |    time_elapsed         | 927           |
# |    total_timesteps      | 6656          |
# | train/                  |               |
# |    approx_kl            | 1.4504767e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0124        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 28.3          |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000151     |
# |    value_loss           | 80.7          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 14            |
# |    time_elapsed         | 1014          |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 1.4953315e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00445      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.135         |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000301     |
# |    value_loss           | 0.348         |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 7              |
# |    iterations           | 15             |
# |    time_elapsed         | 1095           |
# |    total_timesteps      | 7680           |
# | train/                  |                |
# |    approx_kl            | 1.26406085e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.95          |
# |    explained_variance   | 0.072          |
# |    learning_rate        | 1e-06          |
# |    loss                 | 0.0735         |
# |    n_updates            | 140            |
# |    policy_gradient_loss | -0.000224      |
# |    value_loss           | 0.224          |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 16           |
# |    time_elapsed         | 1175         |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 4.991889e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.028       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0762       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000113    |
# |    value_loss           | 0.238        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 17            |
# |    time_elapsed         | 2885          |
# |    total_timesteps      | 8704          |
# | train/                  |               |
# |    approx_kl            | 5.9781596e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0061       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0878        |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000126     |
# |    value_loss           | 0.248         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 18            |
# |    time_elapsed         | 3003          |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 1.5474623e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0171        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 114           |
# |    n_updates            | 170           |
# |    policy_gradient_loss | 0.000235      |
# |    value_loss           | 352           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 19            |
# |    time_elapsed         | 3081          |
# |    total_timesteps      | 9728          |
# | train/                  |               |
# |    approx_kl            | 4.4171466e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.071         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.191         |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -2.54e-05     |
# |    value_loss           | 1.27          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 20            |
# |    time_elapsed         | 3167          |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 1.0873657e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0945        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.228         |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00025      |
# |    value_loss           | 0.686         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 21            |
# |    time_elapsed         | 3252          |
# |    total_timesteps      | 10752         |
# | train/                  |               |
# |    approx_kl            | 3.1164382e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.118         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.197         |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -4.17e-05     |
# |    value_loss           | 0.518         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3            |
# |    iterations           | 22           |
# |    time_elapsed         | 3338         |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 7.983297e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.00421     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.157        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000193    |
# |    value_loss           | 0.455        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 23            |
# |    time_elapsed         | 3425          |
# |    total_timesteps      | 11776         |
# | train/                  |               |
# |    approx_kl            | 5.2050455e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00991       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.208         |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.00012      |
# |    value_loss           | 0.724         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 24            |
# |    time_elapsed         | 3516          |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 1.1132564e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00864      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.176         |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000207     |
# |    value_loss           | 0.332         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 25            |
# |    time_elapsed         | 3610          |
# |    total_timesteps      | 12800         |
# | train/                  |               |
# |    approx_kl            | 1.0744552e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00584       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.124         |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000169     |
# |    value_loss           | 0.319         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 26            |
# |    time_elapsed         | 3706          |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 2.2011693e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00314      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.224         |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.00037      |
# |    value_loss           | 0.376         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 27            |
# |    time_elapsed         | 3801          |
# |    total_timesteps      | 13824         |
# | train/                  |               |
# |    approx_kl            | 1.4953432e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00187      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.182         |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000301     |
# |    value_loss           | 0.355         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 28            |
# |    time_elapsed         | 3892          |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 3.0886848e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.000559     |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.218         |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000438     |
# |    value_loss           | 0.448         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 29            |
# |    time_elapsed         | 3984          |
# |    total_timesteps      | 14848         |
# | train/                  |               |
# |    approx_kl            | 2.0924956e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0122       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0633        |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000197     |
# |    value_loss           | 0.131         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3            |
# |    iterations           | 30           |
# |    time_elapsed         | 4075         |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 3.895932e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00321     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.109        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000531    |
# |    value_loss           | 0.201        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3            |
# |    iterations           | 31           |
# |    time_elapsed         | 4161         |
# |    total_timesteps      | 15872        |
# | train/                  |              |
# |    approx_kl            | 4.829676e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00708      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0613       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000591    |
# |    value_loss           | 0.14         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 32          |
# |    time_elapsed         | 4247        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 1.80637e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.00175    |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.072       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.000248   |
# |    value_loss           | 0.148       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 33            |
# |    time_elapsed         | 4327          |
# |    total_timesteps      | 16896         |
# | train/                  |               |
# |    approx_kl            | 3.4414814e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0433        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 122           |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000157     |
# |    value_loss           | 265           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3            |
# |    iterations           | 34           |
# |    time_elapsed         | 4407         |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 3.973837e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00734      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 19.4         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000158    |
# |    value_loss           | 47.7         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 35            |
# |    time_elapsed         | 4483          |
# |    total_timesteps      | 17920         |
# | train/                  |               |
# |    approx_kl            | 1.5052268e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0371        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 46.8          |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.000127     |
# |    value_loss           | 97            |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 36            |
# |    time_elapsed         | 4559          |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 1.5955651e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.281         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0979        |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -4.44e-05     |
# |    value_loss           | 0.864         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 37            |
# |    time_elapsed         | 4635          |
# |    total_timesteps      | 18944         |
# | train/                  |               |
# |    approx_kl            | 2.0927284e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0462        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0578        |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000203     |
# |    value_loss           | 0.65          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 38          |
# |    time_elapsed         | 4712        |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 5.51471e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.0109      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0864      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -3.94e-06   |
# |    value_loss           | 0.539       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 39           |
# |    time_elapsed         | 4788         |
# |    total_timesteps      | 19968        |
# | train/                  |              |
# |    approx_kl            | 2.897461e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0424       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0687       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000357    |
# |    value_loss           | 0.362        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 40            |
# |    time_elapsed         | 4868          |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 2.0918553e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.271         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0602        |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.00026      |
# |    value_loss           | 0.34          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 41            |
# |    time_elapsed         | 4948          |
# |    total_timesteps      | 20992         |
# | train/                  |               |
# |    approx_kl            | 1.0459917e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0136        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0849        |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000118     |
# |    value_loss           | 0.249         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 42            |
# |    time_elapsed         | 5030          |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 1.0700431e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0044        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0748        |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000151     |
# |    value_loss           | 0.227         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 43            |
# |    time_elapsed         | 5112          |
# |    total_timesteps      | 22016         |
# | train/                  |               |
# |    approx_kl            | 1.3334793e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0367        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 34.1          |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000114     |
# |    value_loss           | 76.9          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 44            |
# |    time_elapsed         | 5194          |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 1.8847757e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.215         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.139         |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000198     |
# |    value_loss           | 0.455         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 45            |
# |    time_elapsed         | 5276          |
# |    total_timesteps      | 23040         |
# | train/                  |               |
# |    approx_kl            | 2.5639427e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0731        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0549        |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000235     |
# |    value_loss           | 0.302         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 46            |
# |    time_elapsed         | 5358          |
# |    total_timesteps      | 23552         |
# | train/                  |               |
# |    approx_kl            | 2.6237685e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0981        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.106         |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -1.04e-05     |
# |    value_loss           | 0.262         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 47            |
# |    time_elapsed         | 5769          |
# |    total_timesteps      | 24064         |
# | train/                  |               |
# |    approx_kl            | 1.1312775e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0605       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.108         |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000142     |
# |    value_loss           | 0.268         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 48           |
# |    time_elapsed         | 5847         |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 2.286199e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00303     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.105        |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000252    |
# |    value_loss           | 0.251        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 49           |
# |    time_elapsed         | 5928         |
# |    total_timesteps      | 25088        |
# | train/                  |              |
# |    approx_kl            | 9.432086e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0479       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 234          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.000332     |
# |    value_loss           | 622          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 50           |
# |    time_elapsed         | 6008         |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 8.393079e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00917     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.125        |
# |    n_updates            | 490          |
# |    policy_gradient_loss | 8.4e-05      |
# |    value_loss           | 1.14         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 51            |
# |    time_elapsed         | 6090          |
# |    total_timesteps      | 26112         |
# | train/                  |               |
# |    approx_kl            | 2.5029294e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.127         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.171         |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.000264     |
# |    value_loss           | 0.594         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 52           |
# |    time_elapsed         | 6185         |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 1.055724e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0173      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.15         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -3.54e-05    |
# |    value_loss           | 0.602        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 53            |
# |    time_elapsed         | 6278          |
# |    total_timesteps      | 27136         |
# | train/                  |               |
# |    approx_kl            | 1.4174264e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.232         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.163         |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -0.000201     |
# |    value_loss           | 0.447         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 54            |
# |    time_elapsed         | 6369          |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 1.0498916e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0321        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 4.5           |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.00022      |
# |    value_loss           | 18.6          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 55            |
# |    time_elapsed         | 6463          |
# |    total_timesteps      | 28160         |
# | train/                  |               |
# |    approx_kl            | 1.8718536e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.129         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 17.7          |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -0.000252     |
# |    value_loss           | 34.1          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 56          |
# |    time_elapsed         | 6553        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 2.37145e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.00322    |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.134       |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.000321   |
# |    value_loss           | 0.464       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 57           |
# |    time_elapsed         | 6645         |
# |    total_timesteps      | 29184        |
# | train/                  |              |
# |    approx_kl            | 2.093357e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.14         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.000221    |
# |    value_loss           | 0.454        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 58            |
# |    time_elapsed         | 6740          |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 5.3048017e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0763        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.173         |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -0.00058      |
# |    value_loss           | 0.356         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 59            |
# |    time_elapsed         | 6837          |
# |    total_timesteps      | 30208         |
# | train/                  |               |
# |    approx_kl            | 1.3471581e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00969      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.172         |
# |    n_updates            | 580           |
# |    policy_gradient_loss | -0.000187     |
# |    value_loss           | 0.344         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 60           |
# |    time_elapsed         | 6951         |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 9.769457e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0554       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.121        |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -8.33e-05    |
# |    value_loss           | 0.335        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 61          |
# |    time_elapsed         | 7034        |
# |    total_timesteps      | 31232       |
# | train/                  |             |
# |    approx_kl            | 4.43646e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.0959      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0932      |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.000503   |
# |    value_loss           | 0.194       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 62           |
# |    time_elapsed         | 7125         |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 4.090718e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00636      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0463       |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.000331    |
# |    value_loss           | 0.15         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 63            |
# |    time_elapsed         | 7222          |
# |    total_timesteps      | 32256         |
# | train/                  |               |
# |    approx_kl            | 2.6423135e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.148         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0441        |
# |    n_updates            | 620           |
# |    policy_gradient_loss | -0.00029      |
# |    value_loss           | 0.109         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 64            |
# |    time_elapsed         | 7311          |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 1.3990793e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0117        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.753         |
# |    n_updates            | 630           |
# |    policy_gradient_loss | -0.000281     |
# |    value_loss           | 3.18          |
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Train the AI model, this is where the AI model starts to learn
# ----> 2 model.learn(total_timesteps=1000000, callback=callback)
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:271, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     268         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     269         self.logger.dump(step=self.num_timesteps)
# --> 271     self.train()
#     273 callback.on_training_end()
#     275 return self
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:272, in PPO.train(self)
#     270 # Optimization step
#     271 self.policy.optimizer.zero_grad()
# --> 272 loss.backward()
#     273 # Clip grad norm
#     274 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# File ~\anaconda3\lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~\anaconda3\lib\site-packages\torch\autograd\__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
model.save('thisisatestmodel')

# %% [markdown]
# # 4. Test it Out

# %%
# Load model
model = PPO.load('./train/best_model_1000000')

# %%
state = env.reset()

# %%
# Start the game 
state = env.reset()
# Loop through the game
while True: 
    
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
